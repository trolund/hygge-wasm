# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file
df = pd.read_csv("../stats.csv")

# %%
# Sort the data by '% reduction'
df = df.sort_values(by='% reduction', ascending=True)

# remove all rows with 0% reduction
df = df[df['% reduction'] > 0]

# Plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting the sorted data
plt.bar(df['name of file'], df['% reduction'], color='skyblue')

# Adding labels and title
plt.xlabel('Name of File')
plt.ylabel('% Reduction')
plt.title('Reduction in Instructions Count (Sorted by % Reduction)')

# Rotating the x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
# summery statistics of "../stats.csv"
df.describe()
# Out:
#        instr count  instr count after op       diff  % reduction
# count    70.000000             70.000000  70.000000    70.000000
# mean    172.185714            162.128571  10.057143     6.004286
# std     132.168896            123.708390  11.628159     5.319666
# min      31.000000             29.000000   2.000000     0.370000
# 25%      96.250000             84.250000   4.000000     3.570000
# 50%     149.500000            142.000000   7.000000     5.950000
# 75%     214.500000            205.750000  12.000000     7.130000
# max     918.000000            836.000000  82.000000    45.830000

# %%
# Filter out zero values in the '% reduction' column
non_zero_reduction = df['% reduction'][df['% reduction'] != 0]

# Create a histogram
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the histogram
plt.hist(non_zero_reduction, bins=10, color='skyblue', edgecolor='black')

# Adding labels and title
plt.xlabel('% Reduction')
plt.ylabel('Frequency')
plt.title('Histogram of Reduction in Instructions Count (Excluding 0% Reduction)')

# Display the plot
plt.show()

# %%
# Create a scatter plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
plt.scatter(df['instr count'], df['% reduction'], color='skyblue', label='Data Points')

# Adding labels and title
plt.xlabel('Instruction Count')
plt.ylabel('% Reduction')
plt.title('Scatter Plot of Reduction in Instructions Count vs. Instruction Count')

# Display the legend
plt.legend()

# Display the plot
plt.show()

# %%
# Create a line plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
plt.plot(df['name of file'], df['% reduction'], marker='o', color='skyblue', label='Data Trend')

# Adding labels and title
plt.xlabel('Name of File')
plt.ylabel('% Reduction')
plt.title('Line Plot of Reduction in Instructions Count (By File)')

# Rotate the x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the legend
plt.legend()

# Display the plot
plt.show()

# %%
# Create a box plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the box plot
plt.boxplot(df['% reduction'], vert=False, sym='b.')
plt.title('Box Plot of Reduction in Instructions Count')
plt.xlabel('% Reduction')

# Display the plot
plt.show()

# %%
# Sort the data by '% reduction' in descending order
df_sorted = df.sort_values(by='% reduction', ascending=False)

# Select the top 20 tests with the biggest reduction
top_20_tests = df_sorted.head(20)

# Display the top 20 tests
print(top_20_tests)
# Out:
#                  name of file  instr count  instr count after op  diff  \
# 79           023-fun-seq-drop           96                    52    44
# 112                  currying          125                   113    12
# 132           rec-countdown-4          119                   108    11
# 23               000-lambda-7          918                   836    82
# 76   023-fun-nested-closure-2          103                    94     9
# 77     023-fun-nested-closure          103                    94     9
# 130           rec-countdown-2           69                    63     6
# 111                   counter          223                   205    18
# 109                calcualtor          373                   343    30
# 122               hygge-union          203                   187    16
# 12       000-lambda-10-shadow          242                   223    19
# 24               000-lambda-8          371                   342    29
# 133             rec-countdown           55                    51     4
# 124               letClousure          250                   232    18
# 19               000-lambda-3          167                   155    12
# 131           rec-countdown-3          139                   129    10
# 26          000-lambda-simple           56                    52     4
# 75           023-fun-nested-2           56                    52     4
# 82       023-struct-field-sel          169                   157    12
# 20               000-lambda-4          169                   157    12
#
#      % reduction
# 79         45.83
# 112         9.60
# 132         9.24
# 23          8.93
# 76          8.74
# 77          8.74
# 130         8.70
# 111         8.07
# 109         8.04
# 122         7.88
# 12          7.85
# 24          7.82
# 133         7.27
# 124         7.20
# 19          7.19
# 131         7.19
# 26          7.14
# 75          7.14
# 82          7.10
# 20          7.10
